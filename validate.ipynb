# %%
from utils import validate, un_normalize, rgb_to_ycbcr
import torch
import os
from PIL import Image
from models import StyleTransferNet
import numpy as np
from torchvision import transforms
import matplotlib.pyplot as plt
import cv2

# %%
net = StyleTransferNet()

# %%
state_dict = torch.load(os.path.join('SavedModels', 'Vangogh','vangogh_YIQ2.pth'))
net.load_state_dict(state_dict['state_dict'])
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
print('C: {}'.format(state_dict['c']))
print('S: {}'.format(state_dict['s']))
print('Color: {}'.format(state_dict['color']))
# Out:
# C: 100000.0
# S: 700000.0
# Color: 1200.0

# %%
file = 'me.jpg'
image_file = os.path.join('ValidationDataset', file)
img = Image.open(image_file).convert('RGB')

# %%
validate(image=img, style_transfer_net=net, device='cuda')
